# %%
#importaciones de las librerias
import pandas as pd
import numpy as np
import sklearn as sl
import matplotlib.pyplot as plt

# %% [markdown]
# # Ejercicio 1

# %%
data=pd.read_csv("retrasos.csv")#Leemos el fichero csv y pasandolo a dataframe
data
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              9E   N8688C               3280              11953
# 1              9E   N348PQ               3281              13487
# 2              9E   N8896A               3282              11433
# 3              9E   N8886A               3283              15249
# 4              9E   N8974C               3284              10397
# ...           ...      ...                ...                ...
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  \
# 0                     1195302    GNV  ...   ATL     601.0       0.0
# 1                     1348702    MSP  ...   CVG    1359.0       0.0
# 2                     1143302    DTW  ...   CVG    1215.0       0.0
# 3                     1524906    TLH  ...   ATL    1521.0       0.0
# 4                     1039707    ATL  ...   FSM    1847.0       0.0
# ...                       ...    ...  ...   ...       ...       ...
# 583980                1201602    GUM  ...   HNL     749.0       0.0
# 583981                1201602    GUM  ...   SPN     717.0       0.0
# 583982                1495503    SPN  ...   GUM     857.0       0.0
# 583983                1495503    SPN  ...   GUM    1820.0       0.0
# 583984                1201602    GUM  ...   SPN    1636.0       0.0
#
#         DEP_TIME_BLK  ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE  \
# 0          0600-0659     722.0       0.0        0.0       0.0     300.0
# 1          1400-1459    1633.0       0.0        0.0       0.0     596.0
# 2          1200-1259    1329.0       0.0        0.0       0.0     229.0
# 3          1500-1559    1625.0       0.0        0.0       0.0     223.0
# 4          1900-1959    1940.0       0.0        0.0       0.0     579.0
# ...              ...       ...       ...        ...       ...       ...
# 583980     0700-0759    1832.0       0.0        0.0       0.0    3801.0
# 583981     0700-0759     759.0       0.0        0.0       0.0     129.0
# 583982     0900-0959     933.0       0.0        0.0       0.0     129.0
# 583983     1800-1859    1854.0       0.0        0.0       0.0     129.0
# 583984     1600-1659    1719.0       0.0        0.0       0.0     129.0
#
#         Unnamed: 21
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 583980          NaN
# 583981          NaN
# 583982          NaN
# 583983          NaN
# 583984          NaN
#
# [583985 rows x 22 columns]

# %%
data.ARR_DEL15[::3]
# Out:
# 0         0.0
# 3         0.0
# 6         0.0
# 9         0.0
# 12        1.0
#          ...
# 583971    0.0
# 583974    1.0
# 583977    1.0
# 583980    0.0
# 583983    0.0
# Name: ARR_DEL15, Length: 194662, dtype: float64

# %%
data.drop_duplicates(keep=False,inplace=True)#Eliminamos los datos duplicados
data
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              9E   N8688C               3280              11953
# 1              9E   N348PQ               3281              13487
# 2              9E   N8896A               3282              11433
# 3              9E   N8886A               3283              15249
# 4              9E   N8974C               3284              10397
# ...           ...      ...                ...                ...
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  \
# 0                     1195302    GNV  ...   ATL     601.0       0.0
# 1                     1348702    MSP  ...   CVG    1359.0       0.0
# 2                     1143302    DTW  ...   CVG    1215.0       0.0
# 3                     1524906    TLH  ...   ATL    1521.0       0.0
# 4                     1039707    ATL  ...   FSM    1847.0       0.0
# ...                       ...    ...  ...   ...       ...       ...
# 583980                1201602    GUM  ...   HNL     749.0       0.0
# 583981                1201602    GUM  ...   SPN     717.0       0.0
# 583982                1495503    SPN  ...   GUM     857.0       0.0
# 583983                1495503    SPN  ...   GUM    1820.0       0.0
# 583984                1201602    GUM  ...   SPN    1636.0       0.0
#
#         DEP_TIME_BLK  ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE  \
# 0          0600-0659     722.0       0.0        0.0       0.0     300.0
# 1          1400-1459    1633.0       0.0        0.0       0.0     596.0
# 2          1200-1259    1329.0       0.0        0.0       0.0     229.0
# 3          1500-1559    1625.0       0.0        0.0       0.0     223.0
# 4          1900-1959    1940.0       0.0        0.0       0.0     579.0
# ...              ...       ...       ...        ...       ...       ...
# 583980     0700-0759    1832.0       0.0        0.0       0.0    3801.0
# 583981     0700-0759     759.0       0.0        0.0       0.0     129.0
# 583982     0900-0959     933.0       0.0        0.0       0.0     129.0
# 583983     1800-1859    1854.0       0.0        0.0       0.0     129.0
# 583984     1600-1659    1719.0       0.0        0.0       0.0     129.0
#
#         Unnamed: 21
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 583980          NaN
# 583981          NaN
# 583982          NaN
# 583983          NaN
# 583984          NaN
#
# [583985 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583985 entries, 0 to 583984
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DAY_OF_MONTH           583985 non-null  int64
#  1   DAY_OF_WEEK            583985 non-null  int64
#  2   OP_UNIQUE_CARRIER      583985 non-null  object
#  3   OP_CARRIER_AIRLINE_ID  583985 non-null  int64
#  4   OP_CARRIER             583985 non-null  object
#  5   TAIL_NUM               581442 non-null  object
#  6   OP_CARRIER_FL_NUM      583985 non-null  int64
#  7   ORIGIN_AIRPORT_ID      583985 non-null  int64
#  8   ORIGIN_AIRPORT_SEQ_ID  583985 non-null  int64
#  9   ORIGIN                 583985 non-null  object
#  10  DEST_AIRPORT_ID        583985 non-null  int64
#  11  DEST_AIRPORT_SEQ_ID    583985 non-null  int64
#  12  DEST                   583985 non-null  object
#  13  DEP_TIME               567633 non-null  float64
#  14  DEP_DEL15              567630 non-null  float64
#  15  DEP_TIME_BLK           583985 non-null  object
#  16  ARR_TIME               566924 non-null  float64
#  17  ARR_DEL15              565963 non-null  float64
#  18  CANCELLED              583985 non-null  float64
#  19  DIVERTED               583985 non-null  float64
#  20  DISTANCE               583985 non-null  float64
#  21  Unnamed: 21            0 non-null       float64
# dtypes: float64(8), int64(8), object(6)
# memory usage: 102.5+ MB

# %%
#Eliminamos las columnas repetidas o que no aporten ninguna informacion
data=data.drop(columns=['OP_CARRIER','CANCELLED','DIVERTED','Unnamed: 21'])

# %%
#Agrupa la columna de día del mes de manera que cada uno corresponda a una semana usando una etiqueta de tipo String.
conditionlist = [
    (data['DAY_OF_MONTH'] >= 1) & (data['DAY_OF_MONTH'] <=7),
    (data['DAY_OF_MONTH'] >= 8) & (data['DAY_OF_MONTH'] <=14),
    (data['DAY_OF_MONTH'] >= 15) & (data['DAY_OF_MONTH'] <=22),
    (data['DAY_OF_MONTH'] <= 31)]
choicelist = ['Semana1', 'Semana2', 'Semana3','Semana4']
data['Etiqueta'] = np.select(conditionlist, choicelist, default='Not Specified')
data
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0        N8688C               3280              11953                1195302
# 1        N348PQ               3281              13487                1348702
# 2        N8896A               3282              11433                1143302
# 3        N8886A               3283              15249                1524906
# 4        N8974C               3284              10397                1039707
# ...         ...                ...                ...                    ...
# 583980   N776UA                200              12016                1201602
# 583981   N36280                174              12016                1201602
# 583982   N36280                117              14955                1495503
# 583983   N39726                105              14955                1495503
# 583984   N39726                104              12016                1201602
#
#        ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 0         GNV            10397              1039707  ATL     601.0        0.0
# 1         MSP            11193              1119302  CVG    1359.0        0.0
# 2         DTW            11193              1119302  CVG    1215.0        0.0
# 3         TLH            10397              1039707  ATL    1521.0        0.0
# 4         ATL            11778              1177801  FSM    1847.0        0.0
# ...       ...              ...                  ...  ...       ...        ...
# 583980    GUM            12173              1217305  HNL     749.0        0.0
# 583981    GUM            14955              1495503  SPN     717.0        0.0
# 583982    SPN            12016              1201602  GUM     857.0        0.0
# 583983    SPN            12016              1201602  GUM    1820.0        0.0
# 583984    GUM            14955              1495503  SPN    1636.0        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  DISTANCE Etiqueta
# 0         0600-0659     722.0        0.0     300.0  Semana1
# 1         1400-1459    1633.0        0.0     596.0  Semana1
# 2         1200-1259    1329.0        0.0     229.0  Semana1
# 3         1500-1559    1625.0        0.0     223.0  Semana1
# 4         1900-1959    1940.0        0.0     579.0  Semana1
# ...             ...       ...        ...       ...      ...
# 583980    0700-0759    1832.0        0.0    3801.0  Semana4
# 583981    0700-0759     759.0        0.0     129.0  Semana4
# 583982    0900-0959     933.0        0.0     129.0  Semana4
# 583983    1800-1859    1854.0        0.0     129.0  Semana4
# 583984    1600-1659    1719.0        0.0     129.0  Semana4
#
# [583985 rows x 19 columns]

# %%
#Teniendo en cuenta que la columna DEP_DEL15 indica con un 1 que se ha producido un retraso y con un 0 que no se ha producido ninguno
#Si sumamos la columna DEP_DEL15 segun etiquieta podemos ver la cantidad de vuelos retrasados segun la semana
enero=data.groupby(['Etiqueta'])['DEP_DEL15'].sum()

# %% [markdown]
# # Ejercicio 2

# %%
enero.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Etiqueta'>

# %% [markdown]
# # Ejercicio 3

# %%
#Sumamos la columna DEP_DEL15 segun la compañia y el origen
#Sumando esta columna obtenemos el numero de veces que la compañia ha tenido retrasos segun el origen
ej3= data.groupby(['OP_CARRIER_AIRLINE_ID', 'ORIGIN']).agg(SUM=('DEP_DEL15', 'sum'))
ej31=pd.DataFrame(ej3)
#5 compañías con mas problemas con respecto al aeropuerto de origen
var=ej31.nlargest(5, 'SUM')
var
# Out:
#                                  SUM
# OP_CARRIER_AIRLINE_ID ORIGIN
# 19805                 DFW     2278.0
# 19790                 ATL     2200.0
# 19393                 MDW     1662.0
# 20304                 ORD     1476.0
# 19805                 ORD     1462.0

# %%
#Reseteamos el index para poder escoger las columnas
var1=var.reset_index()

#el eje de las X indica la compañía (OP_CARRIER_AIRLINE_IDF)
x = var1['OP_CARRIER_AIRLINE_ID']
#el eje Y el aeropuerto de origen (ORIGIN)
y = var1['ORIGIN']
#eje z es el numero de retrasos
z = var1['SUM']
 
# Bubble plot
plt.scatter(x, y, s=z, alpha=0.5)
plt.show()

# %% [markdown]
# # Ejercicio 3

# %%
#Guardamos en un dataframe las compañias que mas problemas han tenido, un dataframe para cada compañia
#Como hemos visto en el dataframe anterior
compañia1 = data[data["OP_CARRIER_AIRLINE_ID"] == 19805]
compañia2 = data[data["OP_CARRIER_AIRLINE_ID"] == 19790]
compañia3 = data[data["OP_CARRIER_AIRLINE_ID"] == 19393]
compañia4 = data[data["OP_CARRIER_AIRLINE_ID"] == 20304]
compañia5 = data[data["OP_CARRIER_AIRLINE_ID"] == 19805]
var_x=compañia1.append([compañia2,compañia3,compañia4,compañia5])
var_x
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 223                1            2                AA                  19805
# 224                1            2                AA                  19805
# 225                1            2                AA                  19805
# 226                1            2                AA                  19805
# 227                1            2                AA                  19805
# ...              ...          ...               ...                    ...
# 580517            31            4                AA                  19805
# 580518            31            4                AA                  19805
# 580519            31            4                AA                  19805
# 580520            31            4                AA                  19805
# 580521            31            4                AA                  19805
#
#        TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 223      N838NN                363              10693                1069302
# 224      N838NN                363              12892                1289208
# 225      N922NN                364              11298                1129806
# 226      N820AL                366              12892                1289208
# 227      N961NN                367              12953                1295304
# ...         ...                ...                ...                    ...
# 580517   N770UW               2169              11278                1127805
# 580518   N963UW               2170              10721                1072102
# 580519   N963UW               2170              11278                1127805
# 580520   N944UW               2172              10721                1072102
# 580521   N944UW               2172              12953                1295304
#
#        ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 223       BNA            12892              1289208  LAX    2014.0        1.0
# 224       LAX            10693              1069302  BNA    1327.0        1.0
# 225       DFW            14831              1483106  SJC    1838.0        0.0
# 226       LAX            11298              1129806  DFW    1531.0        1.0
# 227       LGA            13930              1393007  ORD    1227.0        0.0
# ...       ...              ...                  ...  ...       ...        ...
# 580517    DCA            10721              1072102  BOS     822.0        0.0
# 580518    BOS            11278              1127805  DCA    1356.0        0.0
# 580519    DCA            10721              1072102  BOS    1125.0        0.0
# 580520    BOS            12953              1295304  LGA    1755.0        1.0
# 580521    LGA            10721              1072102  BOS    1627.0        1.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  DISTANCE Etiqueta
# 223       1900-1959    2251.0        1.0    1797.0  Semana1
# 224       1200-1259    1926.0        1.0    1797.0  Semana1
# 225       1800-1859    2010.0        0.0    1438.0  Semana1
# 226       1500-1559    2018.0        0.0    1235.0  Semana1
# 227       1200-1259    1407.0        0.0     733.0  Semana1
# ...             ...       ...        ...       ...      ...
# 580517    0800-0859     947.0        0.0     399.0  Semana4
# 580518    1400-1459    1532.0        0.0     399.0  Semana4
# 580519    1100-1159    1235.0        0.0     399.0  Semana4
# 580520    1700-1759    1907.0        1.0     184.0  Semana4
# 580521    1500-1559    1725.0        1.0     184.0  Semana4
#
# [404108 rows x 19 columns]

# %%
origin1 = data[data["ORIGIN"] == "DFW"]
origin2 = data[data["ORIGIN"] == "ATL"]
origin3 = data[data["ORIGIN"] == "MDW"]
origin4 = data[data["ORIGIN"] == "ORD"]
origin5 = data[data["ORIGIN"] == "ORD"]
var_y=origin1.append([origin2,origin3,origin4,origin5])
var_y
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 124                1            2                9E                  20363
# 176                1            2                9E                  20363
# 225                1            2                AA                  19805
# 229                1            2                AA                  19805
# 232                1            2                AA                  19805
# ...              ...          ...               ...                    ...
# 583957            31            4                UA                  19977
# 583960            31            4                UA                  19977
# 583974            31            4                UA                  19977
# 583976            31            4                UA                  19977
# 583978            31            4                UA                  19977
#
#        TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 124      N906XJ               3390              11298                1129806
# 176      N903XJ               3435              11298                1129806
# 225      N922NN                364              11298                1129806
# 229      N929AA                368              11298                1129806
# 232      N9620D                371              11298                1129806
# ...         ...                ...                ...                    ...
# 583957      NaN                220              13930                1393007
# 583960   N773UA                219              13930                1393007
# 583974   N37510                206              13930                1393007
# 583976   N75861                204              13930                1393007
# 583978   N779UA                202              13930                1393007
#
#        ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 124       DFW            11433              1143302  DTW    1124.0        0.0
# 176       DFW            13487              1348702  MSP    1122.0        1.0
# 225       DFW            14831              1483106  SJC    1838.0        0.0
# 229       DFW            14747              1474703  SEA    1454.0        0.0
# 232       DFW            10693              1069302  BNA    1442.0        0.0
# ...       ...              ...                  ...  ...       ...        ...
# 583957    ORD            13487              1348702  MSP       NaN        NaN
# 583960    ORD            12173              1217305  HNL    1006.0        0.0
# 583974    ORD            13204              1320402  MCO     826.0        1.0
# 583976    ORD            12892              1289208  LAX     813.0        1.0
# 583978    ORD            13830              1383002  OGG    1027.0        1.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  DISTANCE Etiqueta
# 124       1100-1159    1438.0        0.0     986.0  Semana1
# 176       1100-1159    1318.0        0.0     852.0  Semana1
# 225       1800-1859    2010.0        0.0    1438.0  Semana1
# 229       1400-1459    1701.0        0.0    1660.0  Semana1
# 232       1400-1459    1616.0        0.0     631.0  Semana1
# ...             ...       ...        ...       ...      ...
# 583957    1900-1959       NaN        NaN     334.0  Semana4
# 583960    1000-1059    1445.0        0.0    4243.0  Semana4
# 583974    0800-0859    1200.0        1.0    1005.0  Semana4
# 583976    0700-0759    1028.0        0.0    1744.0  Semana4
# 583978    1000-1059    1457.0        0.0    4184.0  Semana4
#
# [113060 rows x 19 columns]

# %%
#Sumamos la columna ARR_DEL15 segun el aeropuerto de destino
#Sumando esta columna obtenemos el numero de veces que el aeropuerto de destino ha tenido retrasos
retrasos_destino= data.groupby(['DEST_AIRPORT_ID']).agg(SUM=('ARR_DEL15', 'sum'))
retrasos_destino=pd.DataFrame(retrasos_destino)
#5 aeropuertos con mas retrasos
var_destino=retrasos_destino.nlargest(5, 'SUM')
var_destino
# Out:
#                     SUM
# DEST_AIRPORT_ID
# 13930            6441.0
# 12953            4836.0
# 11298            4282.0
# 10397            3931.0
# 14771            3642.0

# %%
#Usa los diagramas de cajas donde cada uno de los 5 aeropuertos de destino con mas retrasos.
x=var_destino['SUM']
plt.boxplot(x)
plt.show()

# %% [markdown]
# Podemos ver que la mayoria de los retrasos segun el aeropuerto de destino se encuentra entre los 4000 y 5000 retrasos, con una excepcion que se encuentra en los 6400, la media se encuentra entre los 4500 y los 4000

# %% [markdown]
# # Ejercicio 4

# %%
mañana=data[data['DEP_TIME']>=800 & (data['DEP_TIME']<=1500)].count()[0]
tarde=data[data['DEP_TIME']>1500 & (data['DEP_TIME']<=2359) | (data['DEP_TIME']==0000)].count()[0]
noche=data[data['DEP_TIME']>0000 & (data['DEP_TIME']<800)].count()[0]
labels=['mañana','tarde','noche']
plt.pie([mañana,tarde,noche],labels=labels,autopct='%.2f %%')
plt.title('Retrasos segun rango horario')
plt.show()

# %% [markdown]
# Hemos usado un diagrama de quesos para representar la diferencia entre los tres rangos horarios
# Como se puede observar todos los retrasos estan equitativamente repartidos en todos los rangos horarios
